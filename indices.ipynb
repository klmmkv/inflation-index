# %%
import pandas as pd
import numpy as np

# %%
dfinflhistorical = pd.read_csv (r'big-mac-historical-source-data.csv')
dfinflhistorical
# Out:
#               name iso_a3 currency_code  local_price  dollar_ex  \
# 0    United States    USA           USD         1.60       1.00
# 1        Australia    AUS           AUD         1.75       1.64
# 2          Belgium    BEL           BEF        90.00      42.00
# 3           Brazil    BRA           BRC         2.50      13.80
# 4          Britain    GBR           GBP         1.10       0.67
# ..             ...    ...           ...          ...        ...
# 336    South Korea    KOR           KRW      3000.00    1218.00
# 337         Sweden    SWE           SEK        24.00       8.32
# 338    Switzerland    CHE           CHF         5.90       1.48
# 339         Taiwan    TWN           TWD        70.00      33.20
# 340       Thailand    THA           THB        52.00      37.60
#
#                      date
# 0    1986-09-01T00:00:00Z
# 1    1986-09-01T00:00:00Z
# 2    1986-09-01T00:00:00Z
# 3    1986-09-01T00:00:00Z
# 4    1986-09-01T00:00:00Z
# ..                    ...
# ...

# %%
dfinfl91_99germ = dfinflhistorical[dfinflhistorical.name == 'Germany']
dfinfl91_99germ
# Out:
#         name iso_a3 currency_code  local_price  dollar_ex  \
# 83   Germany    DEU           DEM         4.30       1.67
# 106  Germany    DEU           DEM         4.50       1.64
# 129  Germany    DEU           DEM         4.60       1.58
# 157  Germany    DEU           DEM         4.60       1.71
# 189  Germany    DEU           DEM         4.80       1.38
# 222  Germany    DEU           DEM         4.90       1.52
# 255  Germany    DEU           DEM         4.90       1.71
# 288  Germany    DEU           DEM         4.95       1.84
# 320  Germany    DEU           DEM         4.95       1.82
#
#                      date
# 83   1991-04-01T00:00:00Z
# 106  1992-04-01T00:00:00Z
# 129  1993-04-01T00:00:00Z
# 157  1994-04-01T00:00:00Z
# 189  1995-04-01T00:00:00Z
# 222  1996-04-01T00:00:00Z
# 255  1997-04-01T00:00:00Z
# 288  1998-04-01T00:00:00Z
# 320  1999-03-01T00:00:00Z

# %%
dfinfl = pd.read_csv (r'big-mac-source-data.csv')
dfinfl
# Out:
#                name iso_a3 currency_code  local_price     dollar_ex  \
# 0         Argentina    ARG           ARS         2.50  1.000000e+00
# 1         Australia    AUS           AUD         2.59  1.680000e+00
# 2            Brazil    BRA           BRL         2.95  1.790000e+00
# 3           Britain    GBR           GBP         1.90  6.329114e-01
# 4            Canada    CAN           CAD         2.85  1.470000e+00
# ...             ...    ...           ...          ...           ...
# 1798        Uruguay    URY           UYU       225.00  4.400000e+01
# 1799  United States    USA           USD         5.65  1.000000e+00
# 1800      Venezuela    VEN           VES  30164100.00  3.613989e+06
# 1801        Vietnam    VNM           VND     69000.00  2.302850e+04
# 1802   South Africa    ZAF           ZAR        33.50  1.466250e+01
#
#       GDP_dollar        date
# 0            NaN  2000-04-01
# 1            NaN  2000-04-01
# 2            NaN  2000-04-01
# 3            NaN  2000-04-01
# ...

# %%
dfinfl11_21germ = dfinfl[dfinfl.name == 'Germany']
dfinfl11_21germ
# Out:
#          name iso_a3 currency_code  local_price  dollar_ex  GDP_dollar  \
# 538   Germany    DEU           EUR         3.40   0.697520   40631.243
# 593   Germany    DEU           EUR         3.53   0.788239   40631.243
# 647   Germany    DEU           EUR         3.64   0.824844   40631.243
# 701   Germany    DEU           EUR         3.64   0.736947   44110.989
# 756   Germany    DEU           EUR         3.64   0.777756   44110.989
# 811   Germany    DEU           EUR         3.67   0.737218   44110.989
# 867   Germany    DEU           EUR         3.67   0.742749   42569.471
# 924   Germany    DEU           EUR         3.67   0.863073   44999.496
# 980   Germany    DEU           EUR         3.59   0.912700   47589.972
# 1036  Germany    DEU           EUR         3.59   0.930233   47773.578
# 1092  Germany    DEU           EUR         3.79   0.908306   40996.511
# 1148  Germany    DEU           EUR         3.79   0.955247   40996.511
# ...

# %%
# initialise data of lists.
datainfl = {'Year':['2011', '2012', '2013', '2014','2015','2016','2017','2018', '2019','2020'],
        'Inflation in Percent':[2.1, 2, 1.4, 1, 0.5,0.5,1.5,1.8,1.4,0.5],
           'BigMac Price in Dollar':[2.37, 2.868, 2.755, 2.712, 3.223, 3.391, 3.518, 3.348, 3.643, 3.961]}
 
# Create DataFrame
dfinflger = pd.DataFrame(datainfl)
dfinflger.set_index('Year')
# Out:
#       Inflation in Percent  BigMac Price in Dollar
# Year
# 2011                   2.1                   2.370
# 2012                   2.0                   2.868
# 2013                   1.4                   2.755
# 2014                   1.0                   2.712
# 2015                   0.5                   3.223
# 2016                   0.5                   3.391
# 2017                   1.5                   3.518
# 2018                   1.8                   3.348
# 2019                   1.4                   3.643
# 2020                   0.5                   3.961

# %%
# Inflation X Big Mac Index 2011-2020 Germany.
datainfl = {'Year':['2011', '2012', '2013', '2014','2015','2016','2017','2018', '2019','2020'],
            'Inflation in Percent':[2.1, 2, 1.4, 1, 0.5,0.5,1.5,1.8,1.4,0.5],
            'BigMac Price in Dollar':[2.37, 2.868, 2.755, 2.712, 3.223, 3.391, 3.518, 3.348, 3.643, 3.961]}
 
# Create DataFrame
dfinflger = pd.DataFrame(datainfl)
dfinflger.set_index('Year')
# Out:
#       Inflation in Percent  BigMac Price in Dollar
# Year
# 2011                   2.1                   2.370
# 2012                   2.0                   2.868
# 2013                   1.4                   2.755
# 2014                   1.0                   2.712
# 2015                   0.5                   3.223
# 2016                   0.5                   3.391
# 2017                   1.5                   3.518
# 2018                   1.8                   3.348
# 2019                   1.4                   3.643
# 2020                   0.5                   3.961

# %%
# Inflation X Big Mac Index 2011-2020 Germany.
datainfl = {'Year':['2011', '2012', '2013', '2014','2015','2016','2017','2018', '2019','2020'],
            'ECB Rate':[0.001875, 0.0075, 0.005, 0.0025, 0.0015, 0.0005, 0.0005, 0, 0, 0],
            'BigMac Price in EUR':[3.4, 3.53, 3.64, 3.67, 3.63, 3.69, 3.84, 4.01, 4.13, 4.3]}
 
# Create DataFrame
dfinflger = pd.DataFrame(datainfl)
dfinflger.set_index('Year')
# Out:
#       ECB Rate  BigMac Price in EUR
# Year
# 2011  0.001875                 3.40
# 2012  0.007500                 3.53
# 2013  0.005000                 3.64
# 2014  0.002500                 3.67
# 2015  0.001500                 3.63
# 2016  0.000500                 3.69
# 2017  0.000500                 3.84
# 2018  0.000000                 4.01
# 2019  0.000000                 4.13
# 2020  0.000000                 4.30
